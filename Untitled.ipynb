# %% [markdown]
# <a href="https://colab.research.google.com/github/SathwikVakalapudi/Crop-Recommendation-/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split, GridSearchCV,cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, VotingRegressor, StackingRegressor

import lightgbm as lgb
from xgboost import XGBRegressor
from sklearn.compose import make_column_transformer,ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder,StandardScaler,LabelEncoder,OneHotEncoder

# %%
df=pd.read_csv("/content/train.csv")
df1=pd.read_csv("/content/test.csv")

# %%
df.shape
# Out:
# (1460, 81)

# %%
df1.shape
# Out:
# (1459, 80)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.dtypes[df.dtypes !="O"]
# Out:
# Id                 int64
# MSSubClass         int64
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# ...

# %%
plt.scatter(x='LotFrontage',y='SalePrice',data=df)

# %%
df.query('LotFrontage>300')
#935,1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 934    935          20       RL        313.0    27650   Pave   NaN      IR2
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 934          HLS    AllPub  ...        0    NaN   NaN         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 934      11   2008        WD         Normal     242000
# 1298      1   2008       New        Partial     160000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='LotArea',y='SalePrice',data=df)

# %%
df.query('LotArea>100000')
#250,314,336,707
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 249  250          50       RL          NaN   159000   Pave   NaN      IR2
# 313  314          20       RL        150.0   215245   Pave   NaN      IR3
# 335  336         190       RL          NaN   164660   Grvl   NaN      IR1
# 706  707          20       RL          NaN   115149   Pave   NaN      IR2
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 249         Low    AllPub  ...        0    NaN   NaN        Shed     500
# 313         Low    AllPub  ...        0    NaN   NaN         NaN       0
# 335         HLS    AllPub  ...        0    NaN   NaN        Shed     700
# 706         Low    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 249      6   2007        WD         Normal     277000
# 313      6   2009        WD         Normal     375000
# 335      8   2008        WD         Normal     228950
# ...

# %%
plt.scatter(x='OverallQual',y='SalePrice',data=df)

# %%
plt.scatter(x='OverallCond',y='SalePrice',data=df)

# %%
df.query('OverallCond ==6 and SalePrice>700000')
#379,692
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691  692          60       RL        104.0    21535   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 691         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691      1   2007        WD         Normal     755000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='YearBuilt',y='SalePrice',data=df)

# %%
plt.scatter(x='YearRemodAdd',y='SalePrice',data=df)

# %%
plt.scatter(x='MasVnrArea',y='SalePrice',data=df)

# %%
df.query('MasVnrArea>1000 and SalePrice>700000')
#298,
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 691  692          60       RL        104.0    21535   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 691         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 691      1   2007        WD         Normal     755000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtFinSF1',y='SalePrice',data=df)

# %%
df.query('BsmtFinSF1 >5000')
#1299
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtFinSF2',y='SalePrice',data=df)

# %%
df.query('BsmtFinSF2>1400')
#323,
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 322  323          60       RL         86.0    10380   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 322         Lvl    AllPub  ...        0    NaN  MnPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 322      8   2007        WD         Normal     301000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtUnfSF',y='SalePrice',data=df)

# %%
plt.scatter(x='TotalBsmtSF',y='SalePrice',data=df)

# %%
df.query('TotalBsmtSF>6000')
#1299,
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 1298      1   2008       New        Partial     160000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='1stFlrSF',y='SalePrice',data=df)

# %%
plt.scatter(x='2ndFlrSF',y='SalePrice',data=df)

# %%
plt.scatter(x='LowQualFinSF',y='SalePrice',data=df)

# %%
df.query('LowQualFinSF>550')
#186
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 185  186          75       RM         90.0    22950   Pave   NaN      IR2
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 185         Lvl    AllPub  ...        0    NaN  GdPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 185      6   2006        WD         Normal     475000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='GrLivArea',y='SalePrice',data=df)

# %%
df.query('GrLivArea>4000')
#692,1183,
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 523    524          60       RL        130.0    40094   Pave   NaN      IR1
# 691    692          60       RL        104.0    21535   Pave   NaN      IR1
# 1182  1183          60       RL        160.0    15623   Pave   NaN      IR1
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 523          Bnk    AllPub  ...        0    NaN    NaN         NaN       0
# 691          Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# 1182         Lvl    AllPub  ...      555     Ex  MnPrv         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd    NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 523      10   2007       New        Partial     184750
# 691       1   2007        WD         Normal     755000
# ...

# %%
plt.scatter(x='BsmtFullBath',y='SalePrice',data=df)

# %%
df.query('BsmtFullBath==3')
#739,
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 738  739          90       RL         60.0    10800   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 738         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 738      3   2009        WD         Alloca     179000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='BsmtHalfBath',y='SalePrice',data=df)

# %%
df.query('BsmtHalfBath==2')
#598,955,739,
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 597  598         120       RL         53.0     3922   Pave   NaN      Reg
# 954  955          90       RL         35.0     9400   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 597         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 954         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 597      2   2007       New        Partial     194201
# 954     10   2006        WD        AdjLand     127500
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='BedroomAbvGr',y='SalePrice',data=df)

# %%
df.query('BedroomAbvGr==8')
#636,598,955,739,
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 635  636         190       RH         60.0    10896   Pave  Pave      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 635         Bnk    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 635      3   2007        WD        Abnorml     200000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='KitchenAbvGr',y='SalePrice',data=df)

# %%
df.query('KitchenAbvGr==0')
#49,810,955,636,598,955,739,
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 954  955          90       RL         35.0     9400   Pave   NaN      IR1
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 954         Lvl    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 954     10   2006        WD        AdjLand     127500
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='TotRmsAbvGrd',y='SalePrice',data=df)

# %%
df.query('TotRmsAbvGrd==14')
#636,49,810,955,636,598,955,739
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 635  636         190       RH         60.0    10896   Pave  Pave      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 635         Bnk    AllPub  ...        0    NaN   NaN         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 635      3   2007        WD        Abnorml     200000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='Fireplaces',y='SalePrice',data=df)

# %%
plt.scatter(x='GarageYrBlt',y='SalePrice',data=df)

# %%
plt.scatter(x='GarageCars',y='SalePrice',data=df)

# %%
plt.scatter(x='GarageArea',y='SalePrice',data=df)

# %%
df.query('GarageArea>1200 & SalePrice<300000')
#582,1062,1191,1299,636,49,810,955,636,598,955,739
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 581    582          20       RL         98.0    12704   Pave   NaN      Reg
# 1061  1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
# 1190  1191         190       RL          NaN    32463   Pave   NaN      Reg
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 581          Lvl    AllPub  ...        0    NaN   NaN         NaN       0
# 1061         Low    AllPub  ...        0    NaN   NaN        Shed     560
# 1190         Low    AllPub  ...        0    NaN   NaN         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd   NaN         NaN       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 581       8   2009       New        Partial     253293
# 1061      8   2008     ConLD         Normal      81000
# ...

# %%
plt.scatter(x='WoodDeckSF',y='SalePrice',data=df)

# %%
plt.scatter(x='OpenPorchSF',y='SalePrice',data=df)

# %%
df.query('OpenPorchSF > 500 and SalePrice < 100000')
#496,582,1062,1191,1299,636,49,810,955,636,598,955,739
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 495  496          30  C (all)         60.0     7879   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 495         Lvl    AllPub  ...        0    NaN  GdWo         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 495     11   2009        WD        Abnorml      34900
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='EnclosedPorch',y='SalePrice',data=df)

# %%
df.query('EnclosedPorch>500')
#198,496,582,1062,1191,1299,636,49,810,955,636,598,955,739
# Out:
#       Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197  198          75       RL        174.0    25419   Pave   NaN      Reg
#
#     LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197         Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
#
#     MoSold YrSold  SaleType  SaleCondition  SalePrice
# 197      3   2006        WD        Abnorml     235000
#
# [1 rows x 81 columns]

# %%
plt.scatter(x='3SsnPorch',y='SalePrice',data=df)

# %%
plt.scatter(x='PoolArea',y='SalePrice',data=df)

# %%
df.query('PoolArea>400 & SalePrice<400000')
#198,811,1171,1299,1387,1424,198,496,582,1062,1191,1299,636,49,810,955,636,598,955,739
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 197    198          75       RL        174.0    25419   Pave   NaN      Reg
# 810    811          20       RL         78.0    10140   Pave   NaN      Reg
# 1170  1171          80       RL         76.0     9880   Pave   NaN      Reg
# 1298  1299          60       RL        313.0    63887   Pave   NaN      IR3
# 1386  1387          60       RL         80.0    16692   Pave   NaN      IR1
# 1423  1424          80       RL          NaN    19690   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 197          Lvl    AllPub  ...      512     Ex  GdPrv         NaN       0
# 810          Lvl    AllPub  ...      648     Fa  GdPrv         NaN       0
# 1170         Lvl    AllPub  ...      576     Gd  GdPrv         NaN       0
# 1298         Bnk    AllPub  ...      480     Gd    NaN         NaN       0
# ...

# %%
plt.scatter(x='MiscVal',y='SalePrice',data=df)

# %%
df.query('MiscVal>8000')
#347,1231,198,811,1171,1299,1387,1424,198,496,582,1062,1191,1299,636,49,810,955,636,598,955,739
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 346    347          20       RL          NaN    12772   Pave   NaN      IR1
# 1230  1231          90       RL          NaN    18890   Pave   NaN      IR1
#
#      LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal  \
# 346          Lvl    AllPub  ...        0    NaN   NaN        Gar2   15500
# 1230         Lvl    AllPub  ...        0    NaN   NaN        Gar2    8300
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# 346       4   2007        WD         Normal     151500
# 1230      8   2007        WD         Normal     190000
#
# [2 rows x 81 columns]

# %%
plt.scatter(x='MoSold',y='SalePrice',data=df)

# %%
values = [347, 1231, 198, 811, 1171, 1299, 1387, 1424, 198, 496, 441, 186, 1183, 524, 707, 314, 250, 379, 629, 524, 582, 1062, 1191, 1299, 636, 49, 810, 955, 636, 598, 955, 739]

# %%
df=df[df.Id.isin(values)==False]

# %%
pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).head(20)
# Out:
#                  0
# PoolQC        1433
# MiscFeature   1384
# Alley         1343
# Fence         1161
# MasVnrType     858
# FireplaceQu    682
# LotFrontage    253
# GarageYrBlt     76
# GarageCond      76
# GarageType      76
# GarageFinish    76
# GarageQual      76
# BsmtFinType2    38
# BsmtExposure    38
# BsmtQual        37
# BsmtCond        37
# BsmtFinType1    37
# MasVnrArea       8
# Electrical       1
# Id               0

# %%
df['MiscFeature'].unique()
# Out:
# array([nan, 'Shed', 'Othr'], dtype=object)

# %%
df['Alley'].unique()
# Out:
# array([nan, 'Grvl', 'Pave'], dtype=object)

# %%
df['Alley'].fillna('NO',inplace=True)
df1['Alley'].fillna('NO',inplace=True)
# Out:
# <ipython-input-1405-b4a91850f14c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Alley'].fillna('NO',inplace=True)

# %%
sns.catplot(data=df,x='Alley',y='SalePrice',kind='box')

# %%
df['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
df['Fence'].fillna('No',inplace=True)
df1['Fence'].fillna('No',inplace=True)

# %%
df['MasVnrType'].unique()
# Out:
# array(['BrkFace', nan, 'Stone', 'BrkCmn'], dtype=object)

# %%
df['MasVnrType'].fillna('No',inplace=True)
df1['MasVnrType'].fillna('No',inplace=True)

# %%
sns.catplot(data=df,x='MasVnrType',y='SalePrice',kind='box')

# %%
df['MasVnrArea'].fillna(0,inplace=True)
df1['MasVnrArea'].fillna(0,inplace=True)

# %%
df['FireplaceQu'].unique()
# Out:
# array([nan, 'TA', 'Gd', 'Fa', 'Ex', 'Po'], dtype=object)

# %%
df['FireplaceQu'].fillna('No',inplace=True)
df1['FireplaceQu'].fillna('No',inplace=True)

# %%
sns.catplot(data=df,x='FireplaceQu',y='SalePrice',kind='box')

# %%
df['LotFrontage'].fillna(0,inplace=True)
df1['LotFrontage'].fillna(0,inplace=True)

# %%
df['GarageCond'].unique()
# Out:
# array(['TA', 'Fa', nan, 'Gd', 'Po', 'Ex'], dtype=object)

# %%
sns.catplot(data=df,x='GarageCond',y='SalePrice',kind='box')

# %%
df['GarageCond'].fillna('No',inplace=True)
df1['GarageCond'].fillna('No',inplace=True)

# %%
df['GarageFinish'].unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %%
sns.catplot(data=df,x='GarageFinish',y='SalePrice',kind='box')

# %%
df['GarageFinish'].fillna('No',inplace=True)
df1['GarageFinish'].fillna('No',inplace=True)

# %%
df['GarageType'].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', nan, 'Basment', '2Types'],
#       dtype=object)

# %%
sns.catplot(data=df,x='GarageType',y='SalePrice',kind='box')

# %%
df['GarageType'].fillna('No',inplace=True)
df1['GarageType'].fillna('No',inplace=True)

# %%
df['GarageQual'].unique()
# Out:
# array(['TA', 'Fa', 'Gd', nan, 'Po', 'Ex'], dtype=object)

# %%
sns.catplot(data=df,x='GarageQual',y='SalePrice',kind='box')

# %%
df['GarageQual'].fillna('No',inplace=True)
df1['GarageQual'].fillna('No',inplace=True)

# %%
df['BsmtFinType2'].unique()
# Out:
# array(['Unf', 'BLQ', nan, 'ALQ', 'Rec', 'LwQ', 'GLQ'], dtype=object)

# %%
df['BsmtFinType2'].fillna('No',inplace=True)
df1['BsmtFinType2'].fillna('No',inplace=True)

# %%
df['BsmtExposure'].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', nan], dtype=object)

# %%
df['BsmtExposure'].fillna('No',inplace=True)
df1['BsmtExposure'].fillna('No',inplace=True)

# %%
df['BsmtQual'].unique()
# Out:
# array(['Gd', 'TA', 'Ex', nan, 'Fa'], dtype=object)

# %%
df['BsmtQual'].fillna('No',inplace=True)
df1['BsmtQual'].fillna('No',inplace=True)

# %%
df['BsmtCond'].unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po'], dtype=object)

# %%
df['BsmtCond'].fillna('No',inplace=True)
df1['BsmtCond'].fillna('No',inplace=True)

# %%
df['BsmtFinType1'].unique()
# Out:
# array(['GLQ', 'ALQ', 'Unf', 'Rec', 'BLQ', nan, 'LwQ'], dtype=object)

# %%
df['BsmtFinType1'].fillna('No',inplace=True)
df1['BsmtFinType1'].fillna('No',inplace=True)

# %%
df['Electrical'].unique()
# Out:
# array(['SBrkr', 'FuseF', 'FuseA', 'FuseP', 'Mix', nan], dtype=object)

# %%
df['Electrical'].fillna('SBrkr',inplace=True)
df1['Electrical'].fillna('SBrkr',inplace=True)

# %%
df=df.drop(columns=['PoolQC','MiscFeature','Alley','Fence','GarageYrBlt','GarageCond','BsmtFinType2'	])

# %%
df1=df1.drop(columns=['PoolQC','MiscFeature','Alley','Fence','GarageYrBlt','GarageCond','BsmtFinType2'	])

# %% [markdown]
# #Numerical features

# %%
# from sklearn.impute import KNNImputer
# imputer = KNNImputer(n_neighbors=5)
# data=df1[numerical_features1].copy()
# cols=data.columns
# features_imputed = imputer.fit_transform(data)
# data_imputed=pd.DataFrame(features_imputed,columns=cols)
# data_imputed.head()
# df1[numerical_features1]=data_imputed

# %%
df['Age'] = df['YrSold'] - df['YearBuilt']
df['AgeAtRemodel'] = df['YrSold'] - df['YearRemodAdd']
df['totalsf']=df['1stFlrSF']+df['2ndFlrSF']+df['BsmtFinSF1']+df['BsmtFinSF2']
df['FinishedBasementAreaRatio'] = (df['BsmtFinSF1'] + df['BsmtFinSF2']) / df['TotalBsmtSF']
df['UsableBasementToLivingAreaRatio'] = (df['BsmtFinSF1'] + df['BsmtFinSF2'] + df['BsmtUnfSF']) / df['GrLivArea']
df['TotalOutdoorPorchArea'] = df['OpenPorchSF']  + df['3SsnPorch']
df['TotalPorchArea'] = df['OpenPorchSF']  + df['3SsnPorch']+df['EnclosedPorch']+df['ScreenPorch']
df['TotalOutdoorSpace'] = df['TotalOutdoorPorchArea'] + df['WoodDeckSF'] + df['PoolArea']
df['NoOfBathrooms']=(df['FullBath'] + 0.5*df['HalfBath']+df['BsmtFullBath']+0.5*df['BsmtHalfBath'])
df['TotalFinishedSF'] = df['GrLivArea'] + df['BsmtFinSF1'] + df['BsmtFinSF2']
df['FinishedBasementRatio'] = (df['BsmtFinSF1'] + df['BsmtFinSF2']) / df['GrLivArea']
df['total_area']=df['GrLivArea']+df['TotalBsmtSF']
df['Living_area_ratio']: df['GrLivArea'] / df['LotArea']

# %%
df1['Age'] = df1['YrSold'] - df1['YearBuilt']
df1['AgeAtRemodel'] = df1['YrSold'] - df1['YearRemodAdd']
df1['totalsf']=df1['1stFlrSF']+df1['2ndFlrSF']+df1['BsmtFinSF1']+df1['BsmtFinSF2']
df1['FinishedBasementAreaRatio'] = (df1['BsmtFinSF1'] + df1['BsmtFinSF2']) / df1['TotalBsmtSF']
df1['UsableBasementToLivingAreaRatio'] = (df1['BsmtFinSF1'] + df1['BsmtFinSF2'] + df1['BsmtUnfSF']) / df1['GrLivArea']
df1['TotalOutdoorPorchArea'] = df1['OpenPorchSF']  + df1['3SsnPorch']
df1['TotalPorchArea'] = df1['OpenPorchSF']  + df1['3SsnPorch']+df1['EnclosedPorch']+df1['ScreenPorch']
df1['TotalOutdoorSpace'] = df1['TotalOutdoorPorchArea'] + df1['WoodDeckSF'] + df1['PoolArea']
df1['NoOfBathrooms']=(df1['FullBath'] + 0.5*df1['HalfBath']+df1['BsmtFullBath']+0.5*df1['BsmtHalfBath'])
df1['TotalFinishedSF'] = df1['GrLivArea'] + df1['BsmtFinSF1'] + df1['BsmtFinSF2']
df1['FinishedBasementRatio'] = (df1['BsmtFinSF1'] + df1['BsmtFinSF2']) / df1['GrLivArea']
df1['total_area']=df1['GrLivArea']+df1['TotalBsmtSF']
df1['Living_area_ratio']: df1['GrLivArea'] / df1['LotArea']

# %%
df.drop(['Id','YrSold','YearRemodAdd','1stFlrSF','2ndFlrSF','BsmtFinSF1','BsmtFinSF2','GrLivArea','TotalBsmtSF','FullBath','HalfBath','BsmtFullBath','BsmtHalfBath','OpenPorchSF','3SsnPorch','EnclosedPorch','ScreenPorch'],axis=1,inplace=True)
df1.drop(['Id','YrSold','YearRemodAdd','1stFlrSF','2ndFlrSF','BsmtFinSF1','BsmtFinSF2','GrLivArea','TotalBsmtSF','FullBath','HalfBath','BsmtFullBath','BsmtHalfBath','OpenPorchSF','3SsnPorch','EnclosedPorch','ScreenPorch'],axis=1,inplace=True)

# %%
df.shape
# Out:
# (1433, 69)

# %%
import matplotlib.pyplot as plt
from matplotlib import cm  # Import the colormap module

correlation_matrix = df.corr(numeric_only=True)
plt.figure(figsize=(20, 12))
sns.heatmap(correlation_matrix, annot=True, cmap=cm.coolwarm, fmt=".2f")
plt.show()

# %%
df=df.drop(columns=['YearBuilt','GarageArea','OverallQual','totalsf','total_area','FinishedBasementAreaRatio','TotalOutdoorSpace'])

# %%
df1=df1.drop(columns=['YearBuilt','GarageArea','OverallQual','totalsf','total_area','FinishedBasementAreaRatio','TotalOutdoorSpace'])

# %%
df1.shape
# Out:
# (1459, 61)

# %%
sns.histplot(
    df,
    x=df["SalePrice"]

)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Count'>

# %%
df['SalePrice']=np.log(df['SalePrice'])

# %%
df['SalePrice']
# Out:
# 0       12.247694
# 1       12.109011
# 2       12.317167
# 3       11.849398
# 4       12.429216
#           ...
# 1455    12.072541
# 1456    12.254863
# 1457    12.493130
# 1458    11.864462
# 1459    11.901583
# Name: SalePrice, Length: 1433, dtype: float64

# %%
df.dtypes[df.dtypes =='O']
# Out:
# MSZoning         object
# Street           object
# LotShape         object
# LandContour      object
# Utilities        object
# LotConfig        object
# LandSlope        object
# Neighborhood     object
# Condition1       object
# Condition2       object
# BldgType         object
# HouseStyle       object
# RoofStyle        object
# RoofMatl         object
# Exterior1st      object
# Exterior2nd      object
# MasVnrType       object
# ExterQual        object
# ExterCond        object
# Foundation       object
# BsmtQual         object
# BsmtCond         object
# BsmtExposure     object
# BsmtFinType1     object
# Heating          object
# HeatingQC        object
# CentralAir       object
# Electrical       object
# KitchenQual      object
# Functional       object
# FireplaceQu      object
# GarageType       object
# GarageFinish     object
# GarageQual       object
# PavedDrive       object
# SaleType         object
# SaleCondition    object
# dtype: object

# %%
ode_cols=['LotShape','LandContour','LandSlope','Utilities','ExterQual','ExterCond','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','CentralAir','KitchenQual','FireplaceQu','GarageQual','GarageFinish','PavedDrive']

# %%
ohe_cols=['Street','LotConfig','Neighborhood','Condition1','Condition2','BldgType','HouseStyle','MasVnrType','Foundation','Electrical','SaleType','MSZoning','SaleCondition','RoofStyle','RoofMatl','Exterior1st','Exterior2nd','Heating','HeatingQC','Functional','GarageType']

# %%
len(ode_cols)
# Out:
# 16

# %%
num_cols=df.select_dtypes(include=['int64','float64']).columns
num_cols=num_cols.drop(['SalePrice'])

# %%
X=df.drop('SalePrice',axis=1)
y=df['SalePrice']

# %%
from sklearn.impute import KNNImputer
imputer = KNNImputer(n_neighbors=5)
data=df1[num_cols].copy()
cols=data.columns
features_imputed = imputer.fit_transform(data)
data_imputed=pd.DataFrame(features_imputed,columns=cols)
df1[num_cols]=data_imputed

# %%
data=X[num_cols].copy()
cols=data.columns
features_imputed = imputer.fit_transform(data)
data_imputed = pd.DataFrame(features_imputed, columns=cols)
X[num_cols] = data_imputed[num_cols]

# %%
for col in df1[ohe_cols]:
  if df1[col].isnull().sum()>0:
    df1[col]=df1[col].fillna(df1[col].mode()[0])
  if df1[col].dtype=="O":
    df1[col]=LabelEncoder().fit_transform(df1[col])

# %%
for col in X[ohe_cols]:
  if X[col].isnull().sum()>0:
    X[col]=X[col].fillna(X[col].mode()[0])
  if X[col].dtype=="O":
    X[col]=LabelEncoder().fit_transform(X[col])

# %%
ordinal_encoder = OrdinalEncoder()
for col in ode_cols:
  if X[col].isnull().sum()>0:
    X[col]=X[col].fillna(X[col].mode()[0])
  if X[col].dtype == "O":
    X[col] = ordinal_encoder.fit_transform(X[col].values.reshape(-1, 1))

# %%
ordinal_encoder = OrdinalEncoder()
for col in ode_cols:
  if df1[col].isnull().sum()>0:
    df1[col]=df1[col].fillna(df1[col].mode()[0])
  if df1[col].dtype == "O":
    df1[col] = ordinal_encoder.fit_transform(df1[col].values.reshape(-1, 1))

# %%
data=X[num_cols].copy()
cols=data.columns
for col in num_cols:
  if X[col].isnull().sum()>0:
    X[col]=X[col].fillna(X[col].mean())

# %%
# from sklearn.preprocessing import MinMaxScaler

# scaler = MinMaxScaler()
# colms=X.columns

# data_to_scale = X[colms]

# scaler.fit(data_to_scale)

# scaled_data = scaler.transform(data_to_scale)
# scaled_data=pd.DataFrame(scaled_data,columns=colms)
# X[colms]=scaled_data

# %%
# scaler = MinMaxScaler()
# colms=df1.columns

# data_to_scale = df1[colms]

# scaler.fit(data_to_scale)

# scaled_data = scaler.transform(data_to_scale)
# scaled_data=pd.DataFrame(scaled_data,columns=colms)
# df1[colms]=scaled_data

# %%
for col in X.columns:
  if X[col].isnull().sum()>0:
    print(col,":",X[col].isnull().sum())

# %%
from sklearn.linear_model import Lasso
from sklearn.feature_selection import SelectFromModel
feature_sel_model=SelectFromModel(Lasso(alpha=0.005,random_state=0))
feature_sel_model.fit(X,y)
feature_sel_model.get_support()
# Out:
# array([ True, False,  True, False, False,  True,  True, False,  True,
#        False,  True, False, False,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#        False,  True, False,  True, False, False,  True,  True, False,
#         True,  True,  True, False,  True,  True,  True,  True, False,
#         True, False,  True,  True, False,  True, False])

# %%
selected_feat = X.columns[(feature_sel_model.get_support())]

print('Total features: {}'.format(X.shape[1]))
print('Selected features: {}'.format(len(selected_feat)))
print('Features with coefficients shrunk to zero: {}'.format(
    np.sum(feature_sel_model.estimator_.coef_ == 0)
))
# Out:
# Total features: 61
# Selected features: 40
# Features with coefficients shrunk to zero: 20

# %%
X=X[selected_feat]
df1=df1[selected_feat]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=25)

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr.predict(X_test)

# %%
Y_pred_lr=lr.predict(df1)

# %%
y_pred_inlakhs
# Out:
# array([127058.70362855, 125292.65556819, 171721.53385221, ...,
#        106676.70925845, 131417.32495031, 180276.62618787])

# %%
y_pred_inlakhs = np.exp(Y_pred_lr)
pred=pd.DataFrame(y_pred_inlakhs)
sub_df=pd.read_csv("/content/sample_submission.csv")
datasets=pd.concat([sub_df['Id'],pred],axis=1)
datasets.columns=['Id','SalePrice']
datasets.to_csv('/content/sample_submission.csv',index=False)

# %%
mean_squared_error(y_test,y_pred_lr)
# Out:
# 0.05995950433410047

# %%
RFR=RandomForestRegressor(random_state=13)

# %%
param_grid_RFR={
    'max_depth':[5,10,15],
    'n_estimators':[100,250,500],
    'min_samples_split':[3,5,10]
}

# %%
rfr_cv=GridSearchCV(RFR,param_grid_RFR,cv=5,scoring='neg_mean_squared_error')

# %%
rfr_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=13),
#              param_grid={'max_depth': [5, 10, 15],
#                          'min_samples_split': [3, 5, 10],
#                          'n_estimators': [100, 250, 500]},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1*rfr_cv.best_score_)
# Out:
# 0.21061451751415747

# %%
rfr_cv.best_params_
# Out:
# {'max_depth': 15, 'min_samples_split': 3, 'n_estimators': 500}

# %%
y_pred_rfr=rfr_cv.predict(df1)

# %%
mean_squared_error(y_test,y_pred_rfr)
# Out:
# 0.05448579125585406

# %%
XGB=XGBRegressor(random_state=13)

# %%
param_grid_XGB={
    'learning_rate':[0.05,0.1,0.2],
    'n_estimators':[300],
    'max_depth':[3],
    'min_child_weight':[1,2,3],
    'gamma':[0,0.1,0.2],
    'subsample':[0.8,0.9,1.0],
    'colsample_bytree':[0.8,0.9,1.0]
}

# %%
xgb_cv=GridSearchCV(XGB,param_grid_XGB,cv=5,scoring='neg_mean_squared_error',n_jobs=-1)

# %%
xgb_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None, device=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     monotone_constraints=None,
#                                     multi_strategy=None, n_estimators=None,
#                                     n_jobs=None, num_parallel_tree=None,
# ...

# %%
np.sqrt(-1*xgb_cv.best_score_)
# Out:
# 0.19046425705764056

# %%
xgb_cv.best_params_
# Out:
# {'colsample_bytree': 0.8,
#  'gamma': 0,
#  'learning_rate': 0.05,
#  'max_depth': 3,
#  'min_child_weight': 2,
#  'n_estimators': 300,
#  'subsample': 0.8}

# %%
y_pred_xgb=xgb_cv.predict(X_test)

# %%
mean_squared_error(y_test,y_pred_xgb)
# Out:
# 0.040940473227958844

# %%
ridge=Ridge()

# %%
param_grid_ridge={
    'alpha':[0.05,0.1,1,3,5,10],
    'solver':['auto','svd','cholesky','lsqr','sparse_cg','sag']
}

# %%
ridge_cv=GridSearchCV(ridge,param_grid_ridge,cv=5,scoring='neg_mean_squared_error',n_jobs=-1)

# %%
ridge_cv.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(), n_jobs=-1,
#              param_grid={'alpha': [0.05, 0.1, 1, 3, 5, 10],
#                          'solver': ['auto', 'svd', 'cholesky', 'lsqr',
#                                     'sparse_cg', 'sag']},
#              scoring='neg_mean_squared_error')

# %%
np.sqrt(-1*ridge_cv.best_score_)
# Out:
# 0.22354537709861594

# %%
ridge_cv.best_params_
# Out:
# {'alpha': 5, 'solver': 'svd'}

# %%
y_pred_ridge=ridge_cv.predict(X_test)

# %%
mean_squared_error(y_test,y_pred_ridge)
# Out:
# 0.06001384415113808

# %%
GBR=GradientBoostingRegressor()

# %%
param_grid_GBR={
    'max_depth':[12,15,20],
    'n_estimators':[200,300,1000],
    'min_samples_leaf':[10,25,50],
    'learning_rate':[0.001,0.01,0.1],
    'max_features':[0.01,0.1,0.7]
}

# %%
gbr_cv=GridSearchCV(GBR,param_grid_GBR,cv=5,scoring='neg_mean_squared_error',n_jobs=-1)

# %%
gbr_cv.fit(X_train,y_train)

# %%
np.sqrt(-1*gbr_cv.best_score_)

# %%
gbr_cv.best_params_

# %%
lgbm_regressor=lgb.LGBMRegressor()

# %%
param_grid_lgbm={
    'boosting_type':['gbdt','dart'],
    'num_leaves':[20,30,40],
    'learning_rate':[0.01,0.05,0.1],
    'n_estimators':[100,200,300]
}

# %%
lgbm_cv=GridSearchCV(lgbm_regressor,param_grid_lgbm,cv=3,scoring='neg_mean_squared_error',n_jobs=-1)

# %%
lgbm_cv.fit(X_train,y_train)

# %%
np.sqrt(-1*lgbm_cv.best_score_)

# %%
vr=VotingRegressor([('gbr',gbr_cv.best_estimator_),
                    ('xgb',xgb_cv.best_estimator_),
                    ('ridge',ridge_cv.best_estimator_)],
                   weights=[2,3,1])

# %%
vr.fit(X_train,y_train)

# %%
y_pred_vr=vr.predict(X_test)

# %%
mean_squared_error(y_test,y_pred_vr)

# %%
estimators=[
    ('gbr',gbr_cv.best_estimator_),
    ('xgb',xgb_cv.best_estimator_),
    ('ridge',ridge_cv.best_estimator_),
    ('lgb',lgbm_cv.best_estimator_),
    ('rfr',rfr_cv.best_estimator_)
]

# %%
stackreg=StackingRegressor(
    estimators=estimators,
    final_estimator=vr
)

# %%
stackreg.fit(X_train,y_train)

# %%
y_pred_stack=stackreg.predict(X_test)

# %%
mean_squared_error(y_test,y_pred_stack,squared=False)

# %%
# df1_preprocess=pipeline.transform(df1)

# %%
y_stacking = np.exp(stackreg.predict(df1_preprocess))
